# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('STRESS.csv')
df.head()
# Out:
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
df.columns
# Out:
# Index(['sr', 'rr', 't', 'lm', 'bo', 'rem', 'sr.1', 'hr', 'sl'], dtype='object')

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='sl',data=df)
# Out:
# <Axes: xlabel='sl', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['lm'],color='red')

plt.subplot(1,2,2)
plt.hist(df['bo'],color='blue')
# Out:
# (array([32., 31., 31., 31., 95., 95., 84., 63., 74., 94.]),
#  array([82. , 83.5, 85. , 86.5, 88. , 89.5, 91. , 92.5, 94. , 95.5, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='orange')
plt.show()

# %%
plt.boxplot(df["rem"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2021fe37750>,
#   <matplotlib.lines.Line2D at 0x2021fe42710>],
#  'caps': [<matplotlib.lines.Line2D at 0x2021fe43290>,
#   <matplotlib.lines.Line2D at 0x2021fe43990>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2021fe36290>],
#  'medians': [<matplotlib.lines.Line2D at 0x2021fe411d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2021fe40910>],
#  'means': []}

# %%
    plt.barh(df['sr.1'],df["bo"]) # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 630 artists>

# %%
sns.violinplot(df['hr'], color='purple')
# Out:
# <Axes: >

# %%
df['t'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['sr'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot
# Out:
# C:\Users\SPIRO25\anaconda3\envs\Arzs\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'sl')
# Out:
# sl
# 3    20.0
# 1    20.0
# 0    20.0
# 2    20.0
# 4    20.0
# Name: count, dtype: float64
