# %% [markdown]
# # GRADIENT BOOSTING CLASSIFIER ALGORITHM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Dataset.csv')
data.head()
# Out:
#    UDI Product ID Type  Air_temperature   Process_temperature   \
# 0    1     M14860    M             298.1                 308.6
# 1    2     L47181    L             298.2                 308.7
# 2    3     L47182    L             298.1                 308.5
# 3    4     L47183    L             298.2                 308.6
# 4    5     L47184    L             298.2                 308.7
#
#    Rotational_speed   Torque   Tool_wear   Target Failure_Type
# 0               1551     42.8           0       0   No Failure
# 1               1408     46.3           3       0   No Failure
# 2               1498     49.4           5       0   No Failure
# 3               1433     39.5           7       0   No Failure
# 4               1408     40.0           9       0   No Failure

# %%
df=data.dropna()

# %%
df.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air_temperature ', 'Process_temperature ',
#        'Rotational_speed ', 'Torque ', 'Tool_wear ', 'Target', 'Failure_Type'],
#       dtype='object')

# %%
df.head()
# Out:
#    UDI Product ID Type  Air_temperature   Process_temperature   \
# 0    1     M14860    M             298.1                 308.6
# 1    2     L47181    L             298.2                 308.7
# 2    3     L47182    L             298.1                 308.5
# 3    4     L47183    L             298.2                 308.6
# 4    5     L47184    L             298.2                 308.7
#
#    Rotational_speed   Torque   Tool_wear   Target Failure_Type
# 0               1551     42.8           0       0   No Failure
# 1               1408     46.3           3       0   No Failure
# 2               1498     49.4           5       0   No Failure
# 3               1433     39.5           7       0   No Failure
# 4               1408     40.0           9       0   No Failure

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Type']=lab.fit_transform(df['Type'])

# %%
del df['UDI']
del df['Product ID']
del df['Type']
del df['Target']

# %%
x1 = df.drop(labels='Failure_Type', axis=1)
y1 = df.loc[:,'Failure_Type']

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros =RandomOverSampler(random_state=42)
x,y=ros.fit_resample(x1,y1)
print("OUR DATASET COUNT         : ", Counter(y1))
print("OVER SAMPLING DATA COUNT  : ", Counter(y))
# Out:
# OUR DATASET COUNT         :  Counter({'No Failure': 9652, 'Heat Dissipation Failure': 112, 'Power Failure': 95, 'Overstrain Failure': 78, 'Tool Wear Failure': 45, 'Random Failures': 18})
# OVER SAMPLING DATA COUNT  :  Counter({'No Failure': 9652, 'Power Failure': 9652, 'Tool Wear Failure': 9652, 'Overstrain Failure': 9652, 'Random Failures': 9652, 'Heat Dissipation Failure': 9652})

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.99012, random_state=42, stratify=y)
print("NUMBER OF TRAIN DATASET    : ", len(x_train))
print("NUMBER OF TEST DATASET      : ", len(x_test))
print("TOTAL NUMBER OF DATASET    : ", len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET    :  572
# NUMBER OF TEST DATASET      :  57340
# TOTAL NUMBER OF DATASET    :  57912

# %%
print("NUMBER OF TRAIN DATASET    : ", len(y_train))
print("NUMBER OF TEST DATASET      : ", len(y_test))
print("TOTAL NUMBER OF DATASET    : ", len(y_train)+len(y_test))
# Out:
# NUMBER OF TRAIN DATASET    :  572
# NUMBER OF TEST DATASET      :  57340
# TOTAL NUMBER OF DATASET    :  57912

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GRB = GradientBoostingClassifier()
GRB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predicted = GRB.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,predicted)
print('THE CLASSIFICATION REPORT OF GradientBoosting:\n\n',cr)
# Out:
# THE CLASSIFICATION REPORT OF GradientBoosting:
#
#                            precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.99      0.97      0.98      9556
#               No Failure       0.95      0.78      0.86      9556
#       Overstrain Failure       0.96      0.97      0.97      9557
#            Power Failure       0.97      0.98      0.97      9557
#          Random Failures       0.89      1.00      0.94      9557
#        Tool Wear Failure       0.94      0.98      0.96      9557
#
#                 accuracy                           0.95     57340
#                macro avg       0.95      0.95      0.95     57340
#             weighted avg       0.95      0.95      0.95     57340

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
print('THE CONFUSION MATRIX SCORE OF GradientBoosting:\n\n\n',cm)
# Out:
# THE CONFUSION MATRIX SCORE OF GradientBoosting:
#
#
#  [[9292  172    0   92    0    0]
#  [  91 7495  199  119 1189  463]
#  [   0    0 9296  118    0  143]
#  [   0    0  189 9368    0    0]
#  [   0    0    0    0 9557    0]
#  [   0  226    0    0    0 9331]]

# %%
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(GRB, x, y, scoring='accuracy')
print('THE CROSS VALIDATION TEST RESULT OF ACCURACY :\n\n\n', accuracy*100)
# Out:
# THE CROSS VALIDATION TEST RESULT OF ACCURACY :
#
#
#  [98.57549858 95.83872917 95.77793127 97.55655327 99.06751856]

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(y_test,predicted)
print("THE ACCURACY SCORE OF GradientBoosting IS :",a*100)
# Out:
# THE ACCURACY SCORE OF GradientBoosting IS : 94.76630624346006

# %%
from sklearn.metrics import hamming_loss
hl = hamming_loss(y_test,predicted)
print("THE HAMMING LOSS OF GradientBoosting IS :",hl*100)
# Out:
# THE HAMMING LOSS OF GradientBoosting IS : 5.233693756539937

# %%
def plot_confusion_matrix(cm, title='THE CONFUSION MATRIX SCORE OF GradientBoosting\n\n', cmap=plt.cm.cool):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

cm1=confusion_matrix(y_test, predicted)
print('THE CONFUSION MATRIX SCORE OF GradientBoosting:\n\n')
print(cm)
plot_confusion_matrix(cm)
# Out:
# THE CONFUSION MATRIX SCORE OF GradientBoosting:
#
#
# [[9292  172    0   92    0    0]
#  [  91 7495  199  119 1189  463]
#  [   0    0 9296  118    0  143]
#  [   0    0  189 9368    0    0]
#  [   0    0    0    0 9557    0]
#  [   0  226    0    0    0 9331]]

# %%
import matplotlib.pyplot as plt
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()
